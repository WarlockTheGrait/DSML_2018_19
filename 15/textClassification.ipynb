# %% [markdown]
# ## Анализ корпуса текста классической русской прозы

# %%
# немного импортов
import sqlalchemy
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import nltk
from nltk.corpus import stopwords

import pymorphy2

from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier

from sklearn import metrics
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, HashingVectorizer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split

import itertools

# %%
db = sqlalchemy.create_engine('sqlite:///data.sqlite')
df = pd.read_sql_query('select * from chunk', db, index_col='chunk_id')
db.dispose()
df.head()
# Out:
#                          author book_id  \
# chunk_id
# 1         Иван Алексеевич Бунин       1
# 2         Иван Алексеевич Бунин       1
# 3         Иван Алексеевич Бунин       1
# 4         Иван Алексеевич Бунин       1
# 5         Иван Алексеевич Бунин       1
#
#                                                        text
# chunk_id
# 1         В знак веры в жизнь вечную, в воскресение из м...
# 2         Ибо он, этот волчец, воистину чудесен. Сорванн...
# 3         Так утешаюсь и я, воскрешая в себе те светонос...
# 4         Роза Иерихона. В живую воду сердца, в чистую в...
# 5         Золотилось солнце на востоке, за туманной синь...

# %%
morph = pymorphy2.MorphAnalyzer()

def is_cyr_word(word):
    for ch in word:
        if not ('а' <= ch <= 'я'):
            return False
    return True

def process_text(text):        
    lower = (word.lower() for word in nltk.wordpunct_tokenize(text))
    cyr = (word for word in lower if is_cyr_word(word))
    norm_form =  (morph.parse(word)[0].normal_form for word in cyr)
        
    return ' '.join(norm_form)
        
def shorten_name(name):
    splited = name.split(' ')
    if len(splited) != 3:
        return name
    
    
    i, o, f = splited
    return '%s.%s. %s' % (i[0], o[0], f)

df['words'] = df['text'].map(process_text)
df['author'] = df['author'].map(shorten_name)

df.to_csv("temp_texts.csv", index = False)

df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-80627eabf0d2> in <module>()
#      23     return '%s.%s. %s' % (i[0], o[0], f)
#      24
# ---> 25 df['words'] = df['text'].map(process_text)
#      26 df['author'] = df['author'].map(shorten_name)
#      27
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    2994         """
#    2995         new_values = super(Series, self)._map_values(
# -> 2996             arg, na_action=na_action)
#    2997         return self._constructor(new_values,
#    2998                                  index=self.index).__finalize__(self)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#    1002
#    1003         # mapper is a function
# -> 1004         new_values = map_f(values, mapper)
#    1005
#    1006         return new_values
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-9-80627eabf0d2> in process_text(text)
#      12     norm_form =  (morph.parse(word)[0].normal_form for word in cyr)
#      13
# ---> 14     return ' '.join(norm_form)
#      15
#      16 def shorten_name(name):
#
# <ipython-input-9-80627eabf0d2> in <genexpr>(.0)
#      10     lower = (word.lower() for word in nltk.wordpunct_tokenize(text))
#      11     cyr = (word for word in lower if is_cyr_word(word))
# ---> 12     norm_form =  (morph.parse(word)[0].normal_form for word in cyr)
#      13
#      14     return ' '.join(norm_form)
#
# ~/anaconda3/lib/python3.6/site-packages/pymorphy2/analyzer.py in parse(self, word)
#     243                 break
#     244
# --> 245         res = self.prob_estimator.apply_to_parses(word, word_lower, res)
#     246
#     247         if self._result_type is None:
#
# ~/anaconda3/lib/python3.6/site-packages/pymorphy2/analyzer.py in apply_to_parses(self, word, word_lower, parses)
#      70
#      71         probs = [self.p_t_given_w.prob(word_lower, tag)
# ---> 72                 for (word, tag, normal_form, score, methods_stack) in parses]
#      73
#      74         if sum(probs) == 0:
#
# ~/anaconda3/lib/python3.6/site-packages/pymorphy2/analyzer.py in <listcomp>(.0)
#      70
#      71         probs = [self.p_t_given_w.prob(word_lower, tag)
# ---> 72                 for (word, tag, normal_form, score, methods_stack) in parses]
#      73
#      74         if sum(probs) == 0:
#
# ~/anaconda3/lib/python3.6/site-packages/pymorphy2/dawg.py in prob(self, word, tag)
#      63     def prob(self, word, tag):
#      64         dawg_key = "%s:%s" % (word, tag)
# ---> 65         return self.get(dawg_key, 0) / self.MULTIPLIER
#
# ~/anaconda3/lib/python3.6/site-packages/dawg_python/dawgs.py in get(self, key, default)
#     451         if not isinstance(key, bytes):
#     452             key = key.encode('utf8')
# --> 453         res = self.b_get_value(key)
#     454         if res == LOOKUP_ERROR:
#     455             return default
#
# ~/anaconda3/lib/python3.6/site-packages/dawg_python/dawgs.py in b_get_value(self, key)
#     457
#     458     def b_get_value(self, key):
# --> 459         return self.dct.find(key)
#     460
#     461
#
# KeyboardInterrupt:

# %%
df = pd.read_csv("temp_texts.csv").dropna()
df[['author', 'text']].groupby(['author']).count()
# Out:
#                    text
# author
# А.П. Платонов     11019
# А.П. Чехов         4359
# А.С. Пушкин         516
# Б.Л. Пастернак     2285
# И.А. Бунин         2490
# И.А. Гончаров     11659
# И.С. Тургенев      6296
# Л.Н. Толстой       4515
# Н.В. Гоголь        1112
# Ф.М. Достоевский   5745

# %%
ru_stop_words = stopwords.words('russian')
print(ru_stop_words[0:20])
train, test = train_test_split(df, test_size=0.33)
# Out:
# ['и', 'в', 'во', 'не', 'что', 'он', 'на', 'я', 'с', 'со', 'как', 'а', 'то', 'все', 'она', 'так', 'его', 'но', 'да', 'ты']

# %%
tf_idf = TfidfVectorizer(max_df=0.7, min_df=5, stop_words=ru_stop_words)
clf = LinearSVC()

pipeline = Pipeline([('tf-idf', tf_idf), ('clf', clf)])

def plot_confusion_matrix(cm, classes,               
                          title='Confusion matrix',
                          cmap=plt.cm.Greens):

    plt.figure(figsize=(20,10))
    
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100.
    
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
      
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, 
                 '%.2f%%' %  cm[i, j],
                 horizontalalignment='center',
                 color='black')

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

    
def pipe(clf, train, test):
    clf.fit(train['words'], train['author'])
    
    pred = clf.predict(test['words'])
    
    score = metrics.f1_score(test['author'], pred, average='micro')
    
    authors = list(train['author'].unique())
    cm = metrics.confusion_matrix(test['author'], pred, labels=authors)
    
    plt.figure(figsize=(20,10))
    plot_confusion_matrix(cm, authors)
    
    return clf, score

clf,score = pipe(pipeline, train, test)

print('F_score: ', score)
plt.show()
# Out:
# F_score:  0.884235408206558

# %% [markdown]
# ## Посмотрим на другой способ представления данных - Word2Vec

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

def chunk_to_sentences(text):
    raw_sentences = tokenizer.tokenize(text.strip())
    sentences = []
    for sentence in raw_sentences:
        lower = (word.lower() for word in nltk.wordpunct_tokenize(sentence))
        cyr = (word for word in lower if is_cyr_word(word))
        norm_form =  list(morph.parse(word)[0].normal_form for word in cyr)
        if len(norm_form) > 0:
            sentences.append(norm_form)
    return sentences
df['sentences'] = df['text'].map(chunk_to_sentences)
rows = []
for i, row in df.iterrows():
    for sent in row.sentences:
        new_row = [' '.join(sent)]
        new_row.extend(row.tolist()[:-1])
        rows.append(new_row)
        
df_sent = pd.DataFrame(rows, columns=['sentences','author','id','test','words'])

df_sent.to_csv("with_sentences.csv", index = False)
df_sent
# Out:
#                                                 sentences         author  id  \
# 227295  очень строгий хозяйка сойтись с муж характер г...
# 227296  очень строгий хозяйка сойтись с муж характер г...
# 227297  очень строгий хозяйка сойтись с муж характер г...
# 227298  евлампий мартын харлов этот похожий на отец хо...
# 227299  евлампий мартын харлов этот похожий на отец хо...
# 227300  евлампий мартын харлов этот похожий на отец хо...
# 227301  евлампий мартын харлов этот похожий на отец хо...
# 227302  гаврил федулыч житков кадетина армейщина дослу...
# 227303  гаврил федулыч житков кадетина армейщина дослу...
# 227304  гаврил федулыч житков кадетина армейщина дослу...
# 227305  гаврил федулыч житков кадетина армейщина дослу...
# 227306  гаврил федулыч житков кадетина армейщина дослу...
# 227307  сувенир бычков настоящее имя он неизвестно про...
# 227308  сувенир бычков настоящее имя он неизвестно про...
# 227309  сувенир бычков настоящее имя он неизвестно про...
# 227310  сувенир бычков настоящее имя он неизвестно про...
# 227311  сувенир бычков настоящее имя он неизвестно про...
# 227312  сувенир бычков настоящее имя он неизвестно про...
# 227313  с один сторона рот зуб нет так что весь лицо н...
# 227314  с один сторона рот зуб нет так что весь лицо н...
# 227315  с один сторона рот зуб нет так что весь лицо н...
# 227316  с один сторона рот зуб нет так что весь лицо н...
# 227317  с один сторона рот зуб нет так что весь лицо н...
# 227318  с один сторона рот зуб нет так что весь лицо н...
# 227319  с один сторона рот зуб нет так что весь лицо н...
#
# [227320 rows x 5 columns]

# %%
df_sent = pd.read_csv("with_sentences.csv")


num_features = 150    
context = 5                                                                                        
min_word_count = 3                        
num_workers = 4       

from gensim.models import word2vec

import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s',\
    level=logging.INFO)

print("Training model...")
model = word2vec.Word2Vec([s.split(' ') for s in df_sent['sentences'].values], workers=num_workers, \
            size=num_features, min_count = min_word_count, \
            window = context)
model.init_sims(replace=True)

model_name = "150features_5context"
model.save(model_name)
# Out:
# Training model...
# 2019-03-13 21:23:59,968 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2019-03-13 21:23:59,969 : INFO : collecting all words and their counts
# 2019-03-13 21:23:59,969 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-03-13 21:24:00,006 : INFO : PROGRESS: at sentence #10000, processed 147056 words, keeping 12525 word types
# 2019-03-13 21:24:00,038 : INFO : PROGRESS: at sentence #20000, processed 257660 words, keeping 17243 word types
# 2019-03-13 21:24:00,073 : INFO : PROGRESS: at sentence #30000, processed 375709 words, keeping 20253 word types
# 2019-03-13 21:24:00,106 : INFO : PROGRESS: at sentence #40000, processed 482450 words, keeping 22580 word types
# 2019-03-13 21:24:00,139 : INFO : PROGRESS: at sentence #50000, processed 593276 words, keeping 24391 word types
# 2019-03-13 21:24:00,171 : INFO : PROGRESS: at sentence #60000, processed 710502 words, keeping 26999 word types
# 2019-03-13 21:24:00,202 : INFO : PROGRESS: at sentence #70000, processed 804102 words, keeping 28155 word types
# 2019-03-13 21:24:00,242 : INFO : PROGRESS: at sentence #80000, processed 946445 words, keeping 30902 word types
# 2019-03-13 21:24:00,275 : INFO : PROGRESS: at sentence #90000, processed 1069157 words, keeping 32706 word types
: INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-03-13 21:24:03,609 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-03-13 21:24:03,614 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-03-13 21:24:03,615 : INFO : EPOCH - 2 : training on 2430937 raw words (1906007 effective words) took 1.1s, 1663039 effective words/s
# 2019-03-13 21:24:04,626 : INFO : EPOCH 3 - PROGRESS: at 83.73% examples, 1594215 words/s, in_qsize 7, out_qsize 0
# 2019-03-13 21:24:04,808 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-03-13 21:24:04,811 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-03-13 21:24:04,813 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-03-13 21:24:04,817 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-03-13 21:24:04,818 : INFO : EPOCH - 3 : training on 2430937 raw words (1905995 effective words) took 1.2s, 1593256 effective words/s
# 2019-03-13 21:24:05,831 : INFO : EPOCH 4 - PROGRESS: at 85.03% examples, 1614507 words/s, in_qsize 7, out_qsize 0
# 2019-03-13 21:24:05,982 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-03-13 21:24:05,985 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-03-13 21:24:05,986 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-03-13 21:24:05,991 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-03-13 21:24:05,991 : INFO : EPOCH - 4 : training on 2430937 raw words (1906326 effective words) took 1.2s, 1634420 effective words/s
# 2019-03-13 21:24:07,004 : INFO : EPOCH 5 - PROGRESS: at 85.80% examples, 1631433 words/s, in_qsize 7, out_qsize 0
# 2019-03-13 21:24:07,189 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-03-13 21:24:07,190 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-03-13 21:24:07,193 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-03-13 21:24:07,197 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-03-13 21:24:07,198 : INFO : EPOCH - 5 : training on 2430937 raw words (1906418 effective words) took 1.2s, 1589998 effective words/s
# 2019-03-13 21:24:07,198 : INFO : training on a 12154685 raw words (9530355 effective words) took 6.0s, 1600179 effective words/s
# 2019-03-13 21:24:07,261 : INFO : precomputing L2-norms of word weight vectors
# 2019-03-13 21:24:07,282 : INFO : saving Word2Vec object under 150features_5context, separately None
# 2019-03-13 21:24:07,283 : INFO : not storing attribute vectors_norm
# 2019-03-13 21:24:07,284 : INFO : not storing attribute cum_table
# 2019-03-13 21:24:08,181 : INFO : saved 150features_5context

# %%
print("лишний - отец сын мать кот: " + model.doesnt_match("отец сын мать кот".split()))
print("лишний - париж москва петербург франция: " + model.doesnt_match("париж москва петербург франция".split())+ "\n")
print(str(model.most_similar("отец")) + "\n")

print(str(model.most_similar("корабль")))
# Out:
# лишний - отец сын мать кот: кот
# лишний - париж москва петербург франция: франция
#
# [('матерь', 0.8525245189666748), ('жена', 0.8452463746070862), ('сын', 0.8392343521118164), ('муж', 0.8227209448814392), ('сестра', 0.8211918473243713), ('мать', 0.8024380803108215), ('дочь', 0.7673129439353943), ('брат', 0.7441561222076416), ('родной', 0.7206870317459106), ('тётка', 0.7018401622772217)]
#
# [('пароход', 0.88112473487854), ('остров', 0.8746684789657593), ('завод', 0.8730131387710571), ('стадо', 0.8620514869689941), ('избушка', 0.8492299318313599), ('батарея', 0.845967710018158), ('запад', 0.8433611392974854), ('судно', 0.8385452628135681), ('мост', 0.8374804258346558), ('север', 0.8341292142868042)]
# /Users/eugeny.malyutin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `doesnt_match` (Method will be removed in 4.0.0, use self.wv.doesnt_match() instead).
#   """Entry point for launching an IPython kernel.
# /Users/eugeny.malyutin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `doesnt_match` (Method will be removed in 4.0.0, use self.wv.doesnt_match() instead).
#
# /Users/eugeny.malyutin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/eugeny.malyutin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """

# %%
from gensim.models.keyedvectors import KeyedVectors
model =  KeyedVectors.load_word2vec_format('180/model.bin', binary=True)
model.vocab = {k[0 : k.index('_')]: v for k,v in model.vocab.items()}

print("лишнее из - отец сын мать кот: " + model.doesnt_match("отец сын мать кот".split()))
print("лишнее из - париж москва петербург франция: " + model.doesnt_match("париж москва петербург франция".split()))
# Out:
# 2019-03-13 21:34:19,502 : INFO : loading projection weights from 180/model.bin
# 2019-03-13 21:34:25,232 : INFO : loaded (189193, 300) matrix from 180/model.bin
# 2019-03-13 21:34:25,461 : INFO : precomputing L2-norms of word weight vectors
# лишнее из - отец сын мать кот: кот
# лишнее из - париж москва петербург франция: франция

# %%
print(str(model.most_similar("корабль")))
# Out:
# [('корабль_NOUN', 0.6028140187263489), ('галер_NOUN', 0.558663547039032), ('судно_NOUN', 0.5416064858436584), ('бригантина_NOUN', 0.5380960702896118), ('судно_ADV', 0.5357674956321716), ('парусник_NOUN', 0.5280559062957764), ('крейсер_PROPN', 0.5267558693885803), ('каравелла_NOUN', 0.52385413646698), ('шкун_NOUN', 0.5212233066558838), ('бота_NOUN', 0.5194622278213501)]

# %%
df = df[df['words'].str.len() > 0].reset_index(drop=True)
tfidf = TfidfVectorizer( stop_words=None, min_df=1)
tfidf = tf_idf.fit(df['words'])
tfidf_matr = tf_idf.transform(df['words'])


def sent_to_vector(row):
    index, sent = (row[0], row[1])
    norm_coeff = 0
    sent_vectors = []
    
    for word in sent.split(' '):
        if word in  model and word in tfidf.vocabulary_:
            tfidf_coef = tfidf_matr[index, tfidf.vocabulary_[word]]
            norm_coeff += tfidf_coef
            sent_vectors.append(model[word])
    return np.sum(sent_vectors,axis = 0) / norm_coeff

df['idx'] = df.index
df['vectors'] = np.array(list(map(sent_to_vector, df[['idx','words']].values)))
# Out:
# /Users/eugeny.malyutin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in double_scalars

# %%
train, test = train_test_split(df[['vectors','author','words']][df["vectors"].apply(lambda x: np.size(x) >10)], test_size = 0.33)

rfc = ExtraTreesClassifier(n_estimators = 120, n_jobs=-1)

rfc.fit(np.vstack(train['vectors'].values), train['author'])
pred = rfc.predict(np.vstack(test['vectors'].values))

score = metrics.f1_score(test['author'], pred, average='micro')

print(score)
# Out:
# 0.46681617067701076

# %%
scores_rfc = []
scores_svc = []
percents = [0.6, 0.4, 0.2, 0.1,  0.08, 0.05, 0.02, 0.005]

for perc in percents:
    print("evaluating percent " + str(perc))
    
    train_it = train.sample(frac = perc)
    
    rfc.fit(np.vstack(train_it['vectors'].values), train_it['author'])
    pred = rfc.predict(np.vstack(test['vectors'].values))
    score = metrics.f1_score(test['author'], pred, average='micro')
    scores_rfc.append(score)
    
    pipeline.fit(train_it['words'], train_it['author'])
    pred = pipeline.predict(test['words'])
    score = metrics.f1_score(test['author'], pred, average='micro')
    scores_svc.append(score)
# Out:
# evaluating percent 0.6
# evaluating percent 0.4
# evaluating percent 0.2
# evaluating percent 0.1
# evaluating percent 0.08
# evaluating percent 0.05
# evaluating percent 0.02
# evaluating percent 0.005

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(percents, scores_rfc, color = 'r')
plt.plot(percents, scores_svc)

# %% [markdown]
# ## eli5 и как работает классификатор

# %%
import eli5
from eli5.lime import TextExplainer

from sklearn.linear_model import SGDClassifier

train, test = train_test_split(df, test_size = 0.33)

clf = SGDClassifier(loss = 'modified_huber')
pipeline = Pipeline([('tf-idf', tf_idf), ('clf', clf)])
pipeline.fit(train['words'],train['author'])
target_names = pipeline.named_steps['clf'].classes_.tolist()

pred = pipeline.predict(test['words'])
score = metrics.f1_score(test['author'], pred, average='micro')
print("F1 score: ", score)
# Out:
# /Users/eugeny.malyutin/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# F1 score:  0.8776289472089217

# %%
te = TextExplainer(random_state=42)
te.fit(test['words'].values[1], pipeline.predict_proba)
print("Real Author: ", test['author'].values[1])
te.show_prediction(target_names=target_names)
# Out:
# Real Author:  А.П. Чехов
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=А.П. Платонов
#
# </b>
#
#
#     (probability <b>0.073</b>, score <b>-2.458</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 98.79%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.362
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 95.88%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.096
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 95.17%); opacity: 0.81" title="0.065">сесть</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.77%); opacity: 0.81" title="0.037">уже</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.31%); opacity: 0.80" title="0.028">тонуть</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.68%); opacity: 0.82" title="0.118">в</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 82.19%); opacity: 0.86" title="0.421">вечерний</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 85.14%); opacity: 0.85" title="-0.325">сумерки</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.84%); opacity: 0.82" title="0.115">и</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 86.70%); opacity: 0.84" title="0.277">солнце</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.22%); opacity: 0.82" title="0.106">блестеть</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.90%); opacity: 0.81" title="-0.035">только</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 92.16%); opacity: 0.82" title="-0.130">вверху</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.16%); opacity: 0.80" title="-0.005">на</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.64%); opacity: 0.81" title="0.039">дорога</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 78.67%); opacity: 0.88" title="-0.545">который</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.68%); opacity: 0.81" title="-0.056">змея</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.59%); opacity: 0.81" title="-0.040">бежать</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.04%); opacity: 0.80" title="0.018">по</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 89.76%); opacity: 0.83" title="0.191">скат</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.34%); opacity: 0.82" title="0.126">снизу</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 93.19%); opacity: 0.82" title="-0.107">вверх</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 85.07%); opacity: 0.85" title="-0.327">возвращаться</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 81.40%); opacity: 0.87" title="0.448">старуха</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.41%); opacity: 0.81" title="0.080">из</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 84.19%); opacity: 0.85" title="-0.355">леса</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.30%); opacity: 0.81" title="0.083">и</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.18%); opacity: 0.80" title="0.030">с</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.27%); opacity: 0.81" title="-0.045">они</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 76.73%); opacity: 0.89" title="0.617">ребята</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.78%); opacity: 0.81" title="-0.073">нести</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 88.81%); opacity: 0.83" title="-0.217">корзина</ ...

# %%
eli5.show_weights(clf, vec=tf_idf
                  , target_names=target_names, horizontal_layout=True, top=20)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=А.П. Платонов
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=А.П. Чехов
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=А.С. Пушкин
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Б.Л. Пастернак
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=И.А. Бунин
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=И.А. Гончаров
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=И.С. Тургенев
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Л.Н. Толстой
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Н.В. Гоголь
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=Ф.М. Достоевский
#
# </b>
#
# top features
#                     </td>
#
#             </tr>
#             <tr>
#
#
#                         <td style="padding: 0px; border: 1px solid black; vertical-align: top;">
#
#
#
#
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; width: 100%;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.12%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.985
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         чагатаев
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.40%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.900
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         пуховый
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.83%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.767
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         копенкин
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.85%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.761
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         дван
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.08%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.401
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         сарториус
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.08%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.401
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         колхоз
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.21%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.363
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         перри
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.62%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.246
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         паровоз
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.63%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.245
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         чепурный
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.68%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.230
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         климчицкий
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.75%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.210
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         иванов
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.91%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.167
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         кирпичник
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.99%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.143
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         филат
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.34%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.047
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         лида
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.43%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.022
#     </td>
#     <td style="padding: 0 0.5em 0
